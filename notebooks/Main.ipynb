# %%
# !pip install -r requirements.txt

# %%
# !ls

# %%
# !python3 /home/jaimin/market-classifier/main.py
# Out:
# ...
# CLEAN ENERGY STOCK MARKET MOVEMENT CLASSIFIER
# SDG #7: Affordable & Clean Energy
# ...
#
# [1/6] Loading Data...
# ...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing ICLN...
#   Processing TAN...
#   Processing ENPH...
#   Processing FSLR...
#   Creating target labels (NO DATA LEAKAGE)...
#   Saved processed data: 468 samples, 146 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ...
# MODEL PERFORMANCE METRICS
# ...
# Training Accuracy:   1.0000
# Test Accuracy:       0.6277
# Test F1-Score:       0.6392
# Test ROC-AUC:        0.6557
#
# Confusion Matrix:
# [[28 14]
#  [21 31]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62        42
#            1       0.69      0.60      0.64        52
#
#     accuracy                           0.63        94
# ...
