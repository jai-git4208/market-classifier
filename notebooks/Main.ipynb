# %%
# !source /home/jaimin/market-classifier/venv/bin/activate

# %%
# !pip install -r requirements.txt

# %%
# !ls
# Out:
# data  Main.ipynb  models  results

# %%
# !python3 /home/jaimin/market-classifier/main.py
# Out:
# ======================================================================
# CLEAN ENERGY STOCK MARKET MOVEMENT CLASSIFIER
# SDG #7: Affordable & Clean Energy
# ======================================================================
#
# [1/6] Loading Data...
# Downloading 3y of data for ['ICLN', 'TAN', 'ENPH', 'FSLR']...
# ✓ Successfully downloaded 753 days of data
#
# [2/6] Engineering Features...
#   Processing ICLN...
#   Processing TAN...
#   Processing ENPH...
#   Processing FSLR...
#   Creating target labels (NO DATA LEAKAGE)...
#   Saved processed data: 719 samples, 146 features
#
# [3/6] Training XGBoost Model...
#   Training set: 575 samples
#   Test set: 144 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE METRICS
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.4653
# Test F1-Score:       0.4122
# Test ROC-AUC:        0.4602
#
# Confusion Matrix:
# [[40 21]
#  [56 27]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.42      0.66      0.51        61
#            1       0.56      0.33      0.41        83
#
#     accuracy                           0.47       144
#    macro avg       0.49      0.49      0.46       144
# weighted avg       0.50      0.47      0.45       144
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/confusion_matrix.png
# ROC curve saved to results/roc_curve.png
# Feature importance plot saved to results/feature_importance.png
#
# Top 10 Most Important Features:
#              feature  importance
#          ICLN_rsi_14    0.019065
#      TAN_close_lag_1    0.016071
#            ICLN_Open    0.014892
#     ENPH_macd_signal    0.014198
#           ICLN_Close    0.013945
# ICLN_price_to_sma_20    0.013847
#     ICLN_close_lag_1    0.013317
#  TAN_rolling_min_14d    0.013136
#          ICLN_sma_10    0.012823
#       ENPH_return_1d    0.012375
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION
# ======================================================================
# Predicted Movement:  DOWN
# Confidence:          76.46%
# P(DOWN):             76.46%
# P(UP):               23.54%
# Model saved to models/xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/clean_energy_data.csv
# ✓ Model saved to: models/xgboost_model.json
# ✓ Results saved to: results/

# %%
print("help")
# Out:
# help
